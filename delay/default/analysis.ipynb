# %%
import pandas as pd

basePath = '.'
fileName = 'user1-session1_QoE.csv'

# %%
data_merged = pd.read_csv(basePath + '/' + '1' + '/' + fileName)

# %%
for i in range(2, 2260):
  data = pd.read_csv(basePath + '/' + str(i) + '/' + fileName)
  data_merged = pd.concat([data_merged,data], ignore_index=True)


data_merged.tail(5)
# Out:
#         Zone   Tile_no   Seg_no   Reso   Seg_d_size   Seg_d_time   Bitrate  \
# 2380939   Z3        34       22    720          0.0     0.000016       0.0
# 2380940   Z3        35       22    720          0.0     0.000016       0.0
# 2380941   Z3        36       22    720          0.0     0.000017       0.0
# 2380942   Z3        37       22    720          0.0     0.000017       0.0
# 2380943   Z3        38       22    720          0.0     0.000019       0.0
#
#           Bitrate1   Buf_lev   Buf_limit  ...   Ref_vp   Local_avg       QoE  \
# 2380939        0.0  1.618292           2  ...      0.0         0.0 -0.000237
# 2380940        0.0  1.618292           2  ...      0.0         0.0 -0.000237
# 2380941        0.0  1.618292           2  ...      0.0         0.0 -0.000237
# 2380942        0.0  1.618292           2  ...      0.0         0.0 -0.000237
# 2380943        0.0  1.618292           2  ...      0.0         0.0 -0.000237
#
#              QoE1        Z1        Z2        Z3  delay  jitter  loss
# 2380939 -0.000237 -0.000237 -0.000237 -0.000237      0       0     0
# 2380940 -0.000237 -0.000237 -0.000237 -0.000237      0       0     0
# 2380941 -0.000237 -0.000237 -0.000237 -0.000237      0       0     0
# 2380942 -0.000237 -0.000237 -0.000237 -0.000237      0       0     0
# 2380943 -0.000237 -0.000237 -0.000237 -0.000237      0       0     0
#
# [5 rows x 21 columns]

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no       Reso    Seg_d_size    Seg_d_time  \
# count  2.380944e+06  2.380944e+06  2380944.0  2.380944e+06  2.380944e+06
# mean   1.602083e+01  1.149713e+01      720.0  3.295651e+00  1.135720e-04
# std    1.193645e+01  6.345497e+00        0.0  2.138966e+02  2.247047e-03
# min    0.000000e+00  1.000000e+00      720.0  0.000000e+00  1.300000e-05
# 25%    5.000000e+00  6.000000e+00      720.0  0.000000e+00  6.800000e-05
# 50%    1.450000e+01  1.100000e+01      720.0  0.000000e+00  7.700000e-05
# 75%    2.625000e+01  1.700000e+01      720.0  0.000000e+00  1.050000e-04
# max    3.800000e+01  2.200000e+01      720.0  3.321600e+04  3.352630e-01
#
#             Bitrate      Bitrate1       Buf_lev   Buf_limit       Elapsed  \
# count  2.380944e+06  2.380944e+06  2.380944e+06   2380944.0  2.380944e+06
# mean   3.076899e+01  3.093595e+01  1.771132e+00         2.0  4.728968e+00
# std    2.034540e+03  2.045844e+03  2.015829e-01         0.0  3.246671e+00
# min    0.000000e+00  0.000000e+00  1.000000e+00         2.0  1.400000e-05
# 25%    0.000000e+00  0.000000e+00  1.696248e+00         2.0  2.077084e+00
# 50%    0.000000e+00  0.000000e+00  1.798495e+00         2.0  5.174040e+00
# 75%    0.000000e+00  0.000000e+00  1.903052e+00         2.0  7.285890e+00
# max    3.216828e+05  3.224800e+05  1.989333e+00         2.0  1.130428e+01
#
#              Ref_vp     Local_avg           QoE          QoE1            Z1  \
# count  2.380944e+06  2.380944e+06  2.380944e+06  2.380944e+06  2.380944e+06
# mean   9.971697e+00  9.971697e+00  1.976326e+02  5.208191e+02  3.237788e+01
# std    6.238761e+02  6.238761e+02  1.136324e+04  2.994539e+04  1.861652e+03
# min    0.000000e+00  0.000000e+00 -3.225000e-04 -3.225000e-04 -3.225000e-04
# 25%    0.000000e+00  0.000000e+00 -2.365000e-04 -2.365000e-04 -2.365000e-04
# 50%    0.000000e+00  0.000000e+00 -2.365000e-04 -2.365000e-04 -2.365000e-04
# 75%    0.000000e+00  0.000000e+00 -2.365000e-04 -2.365000e-04 -2.365000e-04
# max    6.927127e+04  6.927127e+04  6.541209e+05  1.722646e+06  1.073770e+05
#
#                  Z2            Z3      delay     jitter       loss
# count  2.380944e+06  2.380944e+06  2380944.0  2380944.0  2380944.0
# mean   5.832271e+02  3.815092e+03        0.0        0.0        0.0
# std    3.353363e+04  2.193551e+05        0.0        0.0        0.0
# min   -3.225000e-04 -3.225000e-04        0.0        0.0        0.0
# 25%   -2.365000e-04 -2.365000e-04        0.0        0.0        0.0
# 50%   -2.365000e-04 -2.365000e-04        0.0        0.0        0.0
# 75%   -2.365000e-04 -2.365000e-04        0.0        0.0        0.0
# max    1.929857e+06  1.261905e+07        0.0        0.0        0.0

# %%
data_merged.hist()
# Out:
# array([[<Axes: title={'center': ' Tile_no'}>,
#         <Axes: title={'center': ' Seg_no'}>,
#         <Axes: title={'center': ' Reso'}>,
#         <Axes: title={'center': ' Seg_d_size'}>],
#        [<Axes: title={'center': ' Seg_d_time'}>,
#         <Axes: title={'center': ' Bitrate'}>,
#         <Axes: title={'center': ' Bitrate1'}>,
#         <Axes: title={'center': ' Buf_lev'}>],
#        [<Axes: title={'center': ' Buf_limit'}>,
#         <Axes: title={'center': ' Elapsed'}>,
#         <Axes: title={'center': ' Ref_vp'}>,
#         <Axes: title={'center': ' Local_avg'}>],
#        [<Axes: title={'center': 'QoE'}>,
#         <Axes: title={'center': 'QoE1'}>, <Axes: title={'center': 'Z1'}>,
#         <Axes: title={'center': 'Z2'}>],
#        [<Axes: title={'center': 'Z3'}>,
#         <Axes: title={'center': 'delay'}>,
#         <Axes: title={'center': 'jitter'}>,
#         <Axes: title={'center': 'loss'}>]], dtype=object)

# %%
data_merged.boxplot()
# Out:
# <Axes: >
