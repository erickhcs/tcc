# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

basePath000 = './0-0-0/' + folderClient_prefix
basePath003 = './0-0-3/' + folderClient_prefix
basePath0250 = './0-25-0/' + folderClient_prefix
basePath0253 = './0-25-3/' + folderClient_prefix

finalFileBasePath = 'user1-session1_QoE.csv'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 834):
      data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
      final_data = pd.concat([final_data, data], ignore_index=True)

  return final_data

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)
data0250 = run_analysis(basePath0250)
data0253 = run_analysis(basePath0253)

data_merged = pd.concat([data000, data003, data0250, data0253], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data000 = run_analysis(basePath000)
#       2 data003 = run_analysis(basePath003)
#       3 data0250 = run_analysis(basePath0250)
#
# Cell In[30], line 18, in run_analysis(basePath)
#      16   for j in range(1, 834):
#      17     data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
# ---> 18     final_data = pd.concat([final_data, data], ignore_index=True)
#      20 return final_data
#
# KeyboardInterrupt:

# %%
basePath5000 = './50-0-0/' + folderClient_prefix

data5000 = run_analysis(basePath5000)

data_merged = pd.concat([data_merged, data5000], ignore_index=True)

# %%
basePath5003 = './50-0-3/' + folderClient_prefix

data5003 = run_analysis(basePath5003)

data_merged = pd.concat([data_merged, data5003], ignore_index=True)

# %%
basePath50250 = './50-25-0/' + folderClient_prefix

data50250 = run_analysis(basePath50250)

data_merged = pd.concat([data_merged, data50250], ignore_index=True)

# %%
basePath50253 = './50-25-3/' + folderClient_prefix

data50253 = run_analysis(basePath50253)

data_merged = pd.concat([data_merged, data50253], ignore_index=True)

# %%
basePath10000 = './100-0-0/' + folderClient_prefix

data10000 = run_analysis(basePath10000)

data_merged = pd.concat([data_merged, data10000], ignore_index=True)

# %%
basePath10003 = './100-0-3/' + folderClient_prefix

data10003 = run_analysis(basePath10003)

data_merged = pd.concat([data_merged, data10003], ignore_index=True)

# %%
basePath100250 = './100-25-0/' + folderClient_prefix

data100250 = run_analysis(basePath100250)

data_merged = pd.concat([data_merged, data100250], ignore_index=True)

# %%
basePath100253 = './100-25-3/' + folderClient_prefix

data100253 = run_analysis(basePath100253)

data_merged = pd.concat([data_merged, data100253], ignore_index=True)

# %%
basePath15000 = './150-0-0/' + folderClient_prefix

data15000 = run_analysis(basePath15000)

data_merged = pd.concat([data_merged, data15000], ignore_index=True)

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  2.165434e+07  2.165434e+07  2.165434e+07  2.165434e+07  2.165434e+07
# mean   1.602083e+01  6.369832e+00  4.573204e+04  5.994819e-02  1.226878e+07
# std    1.193645e+01  3.923485e+00  6.834015e+04  7.709818e-02  2.670709e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  1.836389e+03
# 25%    5.000000e+00  3.000000e+00  9.160000e+03  4.894000e-03  1.458861e+05
# 50%    1.450000e+01  6.000000e+00  1.734400e+04  5.093200e-02  4.401873e+05
# 75%    2.625000e+01  9.000000e+00  4.639200e+04  9.030200e-02  8.269555e+06
# max    3.800000e+01  1.500000e+01  5.527840e+05  3.855392e+00  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  2.165434e+07  2.165434e+07  21654336.0  2.165434e+07  2.165434e+07
# mean   1.540405e+07  1.131188e+00         2.0  1.170392e+01  8.926968e+06
# std    3.769967e+07  2.562522e-01         0.0  9.970102e+00  1.839264e+07
# min    1.832000e+03  1.000000e+00         2.0  1.100000e-05  3.672778e+02
# 25%    1.473840e+05  1.000000e+00         2.0  3.491542e+00  9.078840e+04
# 50%    4.448800e+05  1.000000e+00         2.0  8.458080e+00  2.772634e+05
# 75%    8.112000e+06  1.096555e+00         2.0  1.887936e+01  6.444787e+06
# max    4.816560e+08  1.999967e+00         2.0  3.861874e+01  1.152804e+08
#
#           Local_avg           QoE          QoE1            Z1            Z2  \
# count  2.165434e+07  2.165434e+07  2.165434e+07  2.165434e+07  2.165434e+07
# mean   8.926968e+06  4.190917e+08  1.026800e+09  1.870185e+07  1.353335e+09
# std    1.839264e+07  6.373949e+08  1.619977e+09  2.406332e+07  2.071772e+09
# min    3.672778e+02  8.523553e+05  2.362503e+06  9.262383e+04  2.546553e+06
# 25%    9.078840e+04  5.542442e+06  1.582762e+07  5.704994e+05  1.687148e+07
# 50%    2.772634e+05  8.860461e+06  2.553432e+07  1.169281e+06  2.664904e+07
# 75%    6.444787e+06  3.403081e+08  6.579225e+08  3.096648e+07  1.072769e+09
# max    1.152804e+08  1.905989e+09  4.733381e+09  8.583908e+07  6.230115e+09
#
#                  Z3         delay        jitter          loss
# count  2.165434e+07  2.165434e+07  2.165434e+07  2.165434e+07
# mean   7.430417e+09  4.121067e+01  1.197920e+01  1.387184e+00
# std    1.191062e+10  4.340146e+01  1.248915e+01  1.495752e+00
# min    1.764210e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.179024e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.966628e+08  5.000000e+01  0.000000e+00  0.000000e+00
# 75%    4.376018e+09  5.000000e+01  2.500000e+01  3.000000e+00
# max    3.506482e+10  1.500000e+02  2.500000e+01  3.000000e+00

# %%
data_merged = data_merged.loc[:, ['QoE', 'delay', 'jitter', 'loss']] 

data_merged.head(5)
# Out:
#             QoE  delay  jitter  loss
# 0  1.823679e+09      0       0     0
# 1  1.823679e+09      0       0     0
# 2  1.823679e+09      0       0     0
# 3  1.823679e+09      0       0     0
# 4  1.823679e+09      0       0     0

# %%
data_merged.corr('spearman')
# Out:
#              QoE     delay    jitter      loss
# QoE     1.000000 -0.933219 -0.091149 -0.094659
# delay  -0.933219  1.000000 -0.068479 -0.094222
# jitter -0.091149 -0.068479  1.000000  0.032306
# loss   -0.094659 -0.094222  0.032306  1.000000
