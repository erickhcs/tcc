# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

basePath000 = './0-0-0/' + folderClient_prefix
basePath003 = './0-0-3/' + folderClient_prefix
basePath0250 = './0-25-0/' + folderClient_prefix
basePath0253 = './0-25-3/' + folderClient_prefix

finalFileBasePath = 'user1-session1_QoE.csv'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 834):
      data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
      final_data = pd.concat([final_data, data], ignore_index=True)

  return final_data

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)
data0250 = run_analysis(basePath0250)
data0253 = run_analysis(basePath0253)

data_merged = pd.concat([data000, data003, data0250, data0253], ignore_index=True)

# %%
basePath5000 = './50-0-0/' + folderClient_prefix

data5000 = run_analysis(basePath5000)

data_merged = pd.concat([data_merged, data5000], ignore_index=True)

# %%
basePath5003 = './50-0-3/' + folderClient_prefix

data5003 = run_analysis(basePath5003)

data_merged = pd.concat([data_merged, data5003], ignore_index=True)

# %%
basePath50250 = './50-25-0/' + folderClient_prefix

data50250 = run_analysis(basePath50250)

data_merged = pd.concat([data_merged, data50250], ignore_index=True)

# %%
data_merged.describe()
# Out:
#                 QoE         delay        jitter          loss       Tile_no  \
# count  1.151539e+07  1.151539e+07  1.151539e+07  1.151539e+07  1.919232e+06
# mean   7.842575e+08  8.333333e+00  1.041667e+01  1.250000e+00  1.602083e+01
# std    6.922280e+08  1.863390e+01  1.232517e+01  1.479020e+00  1.193645e+01
# min    8.386901e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.555414e+08  0.000000e+00  0.000000e+00  0.000000e+00  5.000000e+00
# 50%    3.268781e+08  0.000000e+00  0.000000e+00  0.000000e+00  1.450000e+01
# 75%    1.519320e+09  0.000000e+00  2.500000e+01  3.000000e+00  2.625000e+01
# max    1.905989e+09  5.000000e+01  2.500000e+01  3.000000e+00  3.800000e+01
#
#              Seg_no    Seg_d_size    Seg_d_time       Bitrate      Bitrate1  \
# count  1.919232e+06  1.919232e+06  1.919232e+06  1.919232e+06  1.919232e+06
# mean   6.500000e+00  2.034851e+04  5.873319e-02  3.880364e+05  3.909080e+05
# std    3.452053e+00  1.917674e+04  2.955836e-02  3.721766e+05  3.742701e+05
# min    1.000000e+00  5.424000e+03  5.052900e-02  3.539672e+04  3.541600e+04
# 25%    3.750000e+00  7.688000e+03  5.094900e-02  1.468740e+05  1.492800e+05
# 50%    6.500000e+00  1.426000e+04  5.101100e-02  2.755247e+05  2.760720e+05
# 75%    9.250000e+00  2.358400e+04  5.108900e-02  4.582924e+05  4.648000e+05
# max    1.200000e+01  1.380800e+05  1.874000e-01  2.694349e+06  2.707448e+06
#
#          Buf_lev   Buf_limit       Elapsed        Ref_vp     Local_avg  \
# count  1919232.0   1919232.0  1.919232e+06  1.919232e+06  1.919232e+06
# mean         1.0         2.0  1.551346e+01  2.204318e+05  2.204318e+05
# std          0.0         0.0  9.739705e+00  1.553895e+05  1.553895e+05
# min          1.0         2.0  2.400000e-05  7.915833e+03  7.915833e+03
# 25%          1.0         2.0  7.743562e+00  1.038552e+05  1.038552e+05
# 50%          1.0         2.0  1.551680e+01  1.801977e+05  1.801977e+05
# 75%          1.0         2.0  2.330091e+01  2.889207e+05  2.889207e+05
# max          1.0         2.0  3.109992e+01  9.209355e+05  9.209355e+05
#
#                QoE1            Z1            Z2            Z3
# count  1.919232e+06  1.919232e+06  1.919232e+06  1.919232e+06
# mean   2.553593e+07  1.003872e+06  2.582731e+07  1.966775e+08
# std    9.431016e+03  1.979075e+04  4.774897e+04  7.088638e+04
# min    2.548170e+07  9.290510e+05  2.559932e+07  1.961779e+08
# 25%    2.553112e+07  1.007188e+06  2.581117e+07  1.966431e+08
# 50%    2.553735e+07  1.010287e+06  2.581768e+07  1.966836e+08
# 75%    2.554227e+07  1.012237e+06  2.582417e+07  1.967207e+08
# max    2.555962e+07  1.020298e+06  2.599802e+07  1.968824e+08

# %%
data_merged = data_merged.loc[:, ['QoE', 'delay', 'jitter', 'loss']] 

data_merged.head(5)
# Out:
#             QoE  delay  jitter  loss
# 0  1.823679e+09      0       0     0
# 1  1.823679e+09      0       0     0
# 2  1.823679e+09      0       0     0
# 3  1.823679e+09      0       0     0
# 4  1.823679e+09      0       0     0

# %%
data_merged.corr('spearman')
# Out:
#              QoE     delay    jitter      loss
# QoE     1.000000 -0.645497 -0.365963  0.011499
# delay  -0.645497  1.000000 -0.377964 -0.377964
# jitter -0.365963 -0.377964  1.000000  0.142857
# loss    0.011499 -0.377964  0.142857  1.000000
