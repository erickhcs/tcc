# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

basePath000 = './0-0-0/' + folderClient_prefix
basePath003 = './0-0-3/' + folderClient_prefix
basePath0250 = './0-25-0/' + folderClient_prefix
basePath0253 = './0-25-3/' + folderClient_prefix

finalFileBasePath = 'user1-session1_QoE.csv'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 834):
      data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
      final_data = pd.concat([final_data, data], ignore_index=True)

  return final_data

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)
data0250 = run_analysis(basePath0250)
data0253 = run_analysis(basePath0253)

data_merged = pd.concat([data000, data003, data0250, data0253], ignore_index=True)

# %%
basePath5000 = './50-0-0/' + folderClient_prefix

data5000 = run_analysis(basePath5000)

data_merged = pd.concat([data_merged, data5000], ignore_index=True)

# %%
basePath5003 = './50-0-3/' + folderClient_prefix

data5003 = run_analysis(basePath5003)

data_merged = pd.concat([data_merged, data5003], ignore_index=True)

# %%
basePath50250 = './50-25-0/' + folderClient_prefix

data50250 = run_analysis(basePath50250)

data_merged = pd.concat([data_merged, data50250], ignore_index=True)

# %%
basePath50253 = './50-25-3/' + folderClient_prefix

data50253 = run_analysis(basePath50253)

data_merged = pd.concat([data_merged, data50253], ignore_index=True)

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  1.506086e+07  1.506086e+07  1.506086e+07  1.506086e+07  1.506086e+07
# mean   1.602083e+01  7.355568e+00  5.963483e+04  3.481887e-02  1.757001e+07
# std    1.193645e+01  4.078018e+00  7.772388e+04  5.443222e-02  3.054872e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  2.010695e+03
# 25%    5.000000e+00  4.000000e+00  1.142400e+04  1.413000e-03  3.386859e+05
# 50%    1.450000e+01  7.000000e+00  2.624000e+04  2.344600e-02  2.579737e+06
# 75%    2.625000e+01  1.100000e+01  7.630400e+04  5.100700e-02  1.789298e+07
# max    3.800000e+01  1.500000e+01  5.527840e+05  3.335890e+00  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  1.506086e+07  1.506086e+07  15060864.0  1.506086e+07  1.506086e+07
# mean   2.207737e+07  1.188621e+00         2.0  9.716277e+00  1.279744e+07
# std    4.355701e+07  2.891014e-01         0.0  8.793680e+00  2.090900e+07
# min    2.008000e+03  1.000000e+00         2.0  1.700000e-05  6.707089e+02
# 25%    3.420880e+05  1.000000e+00         2.0  2.821972e+00  2.234676e+05
# 50%    2.635472e+06  1.000000e+00         2.0  6.719507e+00  3.416215e+06
# 75%    1.720000e+07  1.362298e+00         2.0  1.481079e+01  1.346784e+07
# max    4.816560e+08  1.999967e+00         2.0  3.617785e+01  1.152804e+08
#
#           Local_avg           QoE          QoE1            Z1            Z2  \
# count  1.506086e+07  1.506086e+07  1.506086e+07  1.506086e+07  1.506086e+07
# mean   1.279744e+07  6.014273e+08  1.473193e+09  2.674704e+07  1.942348e+09
# std    2.090900e+07  6.891620e+08  1.766006e+09  2.489875e+07  2.243190e+09
# min    6.707089e+02  4.309020e+06  1.262440e+07  3.384880e+05  1.331045e+07
# 25%    2.234676e+05  8.456451e+06  2.552483e+07  1.038122e+06  2.583140e+07
# 50%    3.416215e+06  2.827983e+08  5.743346e+08  2.151731e+07  8.888783e+08
# 75%    1.346784e+07  1.448193e+09  3.576237e+09  5.289328e+07  4.675146e+09
# max    1.152804e+08  1.905989e+09  4.733381e+09  8.583908e+07  6.230115e+09
#
#                  Z3         delay        jitter          loss
# count  1.506086e+07  1.506086e+07  1.506086e+07  1.506086e+07
# mean   1.066001e+10  1.814207e+01  1.109410e+01  1.286412e+00
# std    1.302739e+10  2.404098e+01  1.242069e+01  1.484716e+00
# min    9.329171e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.966043e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    3.794770e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    2.592824e+10  5.000000e+01  2.500000e+01  3.000000e+00
# max    3.506482e+10  5.000000e+01  2.500000e+01  3.000000e+00

# %%
data_merged = data_merged.loc[:, ['QoE', 'delay', 'jitter', 'loss']] 

data_merged.head(5)
# Out:
#             QoE  delay  jitter  loss
# 0  1.823679e+09      0       0     0
# 1  1.823679e+09      0       0     0
# 2  1.823679e+09      0       0     0
# 3  1.823679e+09      0       0     0
# 4  1.823679e+09      0       0     0

# %%
data_merged.corr('spearman')
# Out:
#              QoE     delay    jitter      loss
# QoE     1.000000 -0.832804 -0.149414 -0.072533
# delay  -0.832804  1.000000 -0.149994 -0.190633
# jitter -0.149414 -0.149994  1.000000 -0.126069
# loss   -0.072533 -0.190633 -0.126069  1.000000
