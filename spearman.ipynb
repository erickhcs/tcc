# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

basePath000 = './0-0-0/' + folderClient_prefix
basePath003 = './0-0-3/' + folderClient_prefix
basePath0250 = './0-25-0/' + folderClient_prefix
basePath0253 = './0-25-3/' + folderClient_prefix

finalFileBasePath = 'user1-session1_QoE.csv'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 834):
      data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
      final_data = pd.concat([final_data, data], ignore_index=True)

  return final_data

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)
data0250 = run_analysis(basePath0250)
data0253 = run_analysis(basePath0253)

data_merged = pd.concat([data000, data003, data0250, data0253], ignore_index=True)

# %%
basePath5000 = './50-0-0/' + folderClient_prefix

data5000 = run_analysis(basePath5000)

data_merged = pd.concat([data_merged, data5000], ignore_index=True)

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  9.596160e+06  9.596160e+06  9.596160e+06  9.596160e+06  9.596160e+06
# mean   1.602083e+01  8.000000e+00  8.261389e+04  1.823523e-02  2.737537e+07
# std    1.193645e+01  4.320494e+00  8.860301e+04  4.864555e-02  3.463571e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  2.133420e+03
# 25%    5.000000e+00  4.000000e+00  1.556800e+04  1.033000e-03  3.001687e+06
# 50%    1.450000e+01  8.000000e+00  5.028800e+04  2.182000e-03  1.161350e+07
# 75%    2.625000e+01  1.200000e+01  1.107040e+05  2.173800e-02  4.228131e+07
# max    3.800000e+01  1.500000e+01  5.527840e+05  3.335890e+00  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  9.596160e+06  9.596160e+06   9596160.0  9.596160e+06  9.596160e+06
# mean   3.444784e+07  1.296034e+00         2.0  6.299847e+00  1.997005e+07
# std    5.055501e+07  3.152419e-01         0.0  5.680292e+00  2.333137e+07
# min    2.128000e+03  1.000000e+00         2.0  1.700000e-05  6.707089e+02
# 25%    3.077104e+06  1.000000e+00         2.0  1.843166e+00  3.751711e+06
# 50%    1.028000e+07  1.203670e+00         2.0  5.198316e+00  8.152369e+06
# 75%    4.535200e+07  1.553187e+00         2.0  8.431642e+00  2.894849e+07
# max    4.816560e+08  1.999967e+00         2.0  3.206460e+01  1.152804e+08
#
#           Local_avg           QoE          QoE1            Z1            Z2  \
# count  9.596160e+06  9.596160e+06  9.596160e+06  9.596160e+06  9.596160e+06
# mean   1.997005e+07  9.394188e+08  2.299348e+09  4.140405e+07  3.034787e+09
# std    2.333137e+07  6.561747e+08  1.736013e+09  1.951648e+07  2.146695e+09
# min    6.707089e+02  1.672316e+08  4.187798e+08  8.550002e+06  5.218906e+08
# 25%    3.751711e+06  2.900304e+08  5.892108e+08  2.295497e+07  9.132218e+08
# 50%    8.152369e+06  8.330652e+08  1.990183e+09  4.127901e+07  2.674092e+09
# 75%    2.894849e+07  1.593542e+09  4.072145e+09  5.760014e+07  5.166692e+09
# max    1.152804e+08  1.905989e+09  4.733381e+09  8.583908e+07  6.230115e+09
#
#                  Z3      delay        jitter       loss
# count  9.596160e+06  9596160.0  9.596160e+06  9596160.0
# mean   1.663407e+10        0.0  1.250000e+01        1.5
# std    1.296138e+10        0.0  1.250000e+01        1.5
# min    2.883112e+09        0.0  0.000000e+00        0.0
# 25%    3.892973e+09        0.0  0.000000e+00        0.0
# 50%    1.380856e+10        0.0  1.250000e+01        1.5
# 75%    3.017852e+10        0.0  2.500000e+01        3.0
# max    3.506482e+10        0.0  2.500000e+01        3.0

# %%
data_merged = data_merged.loc[:, ['QoE', 'delay', 'jitter', 'loss']] 

data_merged.head(5)
# Out:
#             QoE  delay  jitter  loss
# 0  1.823679e+09      0       0     0
# 1  1.823679e+09      0       0     0
# 2  1.823679e+09      0       0     0
# 3  1.823679e+09      0       0     0
# 4  1.823679e+09      0       0     0

# %%
data_merged.corr('spearman')
# Out:
#              QoE  delay    jitter      loss
# QoE     1.000000    NaN -0.866025 -0.330083
# delay        NaN    NaN       NaN       NaN
# jitter -0.866025    NaN  1.000000  0.000000
# loss   -0.330083    NaN  0.000000  1.000000
