# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

basePath000 = './0-0-0/' + folderClient_prefix
basePath003 = './0-0-3/' + folderClient_prefix
basePath0250 = './0-25-0/' + folderClient_prefix
basePath0253 = './0-25-3/' + folderClient_prefix

finalFileBasePath = 'user1-session1_QoE.csv'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 834):
      data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
      final_data = pd.concat([final_data, data], ignore_index=True)

  return final_data

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)
data0250 = run_analysis(basePath0250)
data0253 = run_analysis(basePath0253)

data_merged = pd.concat([data000, data003, data0250, data0253], ignore_index=True)

# %%
basePath5000 = './50-0-0/' + folderClient_prefix

data5000 = run_analysis(basePath5000)

data_merged = pd.concat([data_merged, data5000], ignore_index=True)

# %%
basePath5003 = './50-0-3/' + folderClient_prefix

data5003 = run_analysis(basePath5003)

data_merged = pd.concat([data_merged, data5003], ignore_index=True)

# %%
basePath50250 = './50-25-0/' + folderClient_prefix

data50250 = run_analysis(basePath50250)

data_merged = pd.concat([data_merged, data50250], ignore_index=True)

# %%
basePath50253 = './50-25-3/' + folderClient_prefix

data50253 = run_analysis(basePath50253)

data_merged = pd.concat([data_merged, data50253], ignore_index=True)

# %%
basePath10000 = './100-0-0/' + folderClient_prefix

data10000 = run_analysis(basePath10000)

data_merged = pd.concat([data_merged, data10000], ignore_index=True)

# %%
basePath10003 = './100-0-3/' + folderClient_prefix

data10003 = run_analysis(basePath10003)

data_merged = pd.concat([data_merged, data10003], ignore_index=True)

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  1.666440e+07  1.666440e+07  1.666440e+07  1.666440e+07  1.666440e+07
# mean   1.602083e+01  7.179253e+00  5.550364e+04  3.864603e-02  1.590743e+07
# std    1.193645e+01  4.016198e+00  7.507597e+04  5.901171e-02  2.948543e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  1.888075e+03
# 25%    5.000000e+00  4.000000e+00  1.031200e+04  1.651000e-03  2.888863e+05
# 50%    1.450000e+01  7.000000e+00  2.316000e+04  3.061900e-02  1.549137e+06
# 75%    2.625000e+01  1.000000e+01  6.828800e+04  5.105300e-02  1.430719e+07
# max    3.800000e+01  1.500000e+01  5.527840e+05  3.508335e+00  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  1.666440e+07  1.666440e+07  16664400.0  1.666440e+07  1.666440e+07
# mean   1.998137e+07  1.170471e+00         2.0  1.029111e+01  1.158238e+07
# std    4.190370e+07  2.804126e-01         0.0  9.107904e+00  2.022339e+07
# min    1.888000e+03  1.000000e+00         2.0  1.700000e-05  6.707089e+02
# 25%    2.929680e+05  1.000000e+00         2.0  2.986161e+00  1.932901e+05
# 50%    1.588120e+06  1.000000e+00         2.0  7.192527e+00  2.382506e+06
# 75%    1.292800e+07  1.290405e+00         2.0  1.650420e+01  1.074823e+07
# max    4.816560e+08  1.999967e+00         2.0  3.625793e+01  1.152804e+08
#
#           Local_avg           QoE          QoE1            Z1            Z2  \
# count  1.666440e+07  1.666440e+07  1.666440e+07  1.666440e+07  1.666440e+07
# mean   1.158238e+07  5.441291e+08  1.333009e+09  2.424160e+07  1.757200e+09
# std    2.022339e+07  6.782907e+08  1.732988e+09  2.488478e+07  2.206733e+09
# min    6.707089e+02  3.980156e+06  1.057088e+07  3.384880e+05  1.219217e+07
# 25%    1.932901e+05  8.449516e+06  2.411651e+07  1.009907e+06  2.581112e+07
# 50%    2.382506e+06  2.641456e+08  5.451125e+08  1.831607e+07  8.301721e+08
# 75%    1.074823e+07  1.410644e+09  3.518208e+09  5.194465e+07  4.554651e+09
# max    1.152804e+08  1.905989e+09  4.733381e+09  8.583908e+07  6.230115e+09
#
#                  Z3         delay        jitter          loss
# count  1.666440e+07  1.666440e+07  1.666440e+07  1.666440e+07
# mean   9.645999e+09  2.120760e+01  1.243220e+01  1.451303e+00
# std    1.276869e+10  2.471068e+01  1.249982e+01  1.499209e+00
# min    7.557066e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.776294e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    3.583338e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    2.542478e+10  5.000000e+01  2.500000e+01  3.000000e+00
# max    3.506482e+10  5.000000e+01  2.500000e+01  3.000000e+00

# %%
data_merged = data_merged.loc[:, ['QoE', 'delay', 'jitter', 'loss']] 

data_merged.head(5)
# Out:
#             QoE  delay  jitter  loss
# 0  1.823679e+09      0       0     0
# 1  1.823679e+09      0       0     0
# 2  1.823679e+09      0       0     0
# 3  1.823679e+09      0       0     0
# 4  1.823679e+09      0       0     0

# %%
data_merged.corr('spearman')
# Out:
#              QoE     delay    jitter      loss
# QoE     1.000000 -0.856003 -0.261987 -0.230224
# delay  -0.856003  1.000000 -0.006320 -0.037847
# jitter -0.261987 -0.006320  1.000000 -0.001539
# loss   -0.230224 -0.037847 -0.001539  1.000000
