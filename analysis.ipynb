# %%
import pandas as pd

basePath = './delay/default'

path1 = basePath + '/1/user1-session1_QoE.csv'
path2 = basePath + '/2/user1-session1_QoE.csv'
path3 = basePath + '/3/user1-session1_QoE.csv'
path4 = basePath + '/4/user1-session1_QoE.csv'
path5 = basePath + '/5/user1-session1_QoE.csv'

# %%
data1 = pd.read_csv(path1)
data2 = pd.read_csv(path2)
data3 = pd.read_csv(path3)
data4 = pd.read_csv(path4)
data5 = pd.read_csv(path5)

data1.tail(5)
# Out:
#     Zone   Tile_no   Seg_no   Reso   Seg_d_size   Seg_d_time       Bitrate  \
# 139   Z3        34        3    720       6376.0     0.103640  61520.648398
# 140   Z3        35        3    720       6872.0     0.103639  66307.085171
# 141   Z3        36        3    720       6872.0     0.103508  66391.003594
# 142   Z3        37        3    720       6376.0     0.103649  61515.306467
# 143   Z3        38        3    720       6872.0     0.103681  66280.224921
#
#       Bitrate1   Buf_lev   Buf_limit  ...        Ref_vp     Local_avg  \
# 139    61896.0       1.0           2  ...  36974.674534  36974.674534
# 140    66712.0       1.0           2  ...  37931.961889  37931.961889
# 141    66712.0       1.0           2  ...  37948.745573  37948.745573
# 142    61896.0       1.0           2  ...  36973.606148  36973.606148
# 143    66712.0       1.0           2  ...  37926.589839  37926.589839
#
#                QoE          QoE1             Z1            Z2            Z3  \
# ...

# %%
data1.describe()
# Out:
#           Tile_no      Seg_no   Reso    Seg_d_size   Seg_d_time  \
# count  144.000000  144.000000  144.0    144.000000   144.000000
# mean    16.020833    2.000000  720.0  10898.277778     0.117497
# std     11.978109    0.819346    0.0   5725.909660     0.054171
# min      0.000000    1.000000  720.0   5424.000000     0.102462
# 25%      5.000000    1.000000  720.0   6872.000000     0.103510
# 50%     14.500000    2.000000  720.0   8192.000000     0.103635
# 75%     26.250000    3.000000  720.0  14272.000000     0.103645
# max     38.000000    3.000000  720.0  33216.000000     0.334993
#
#              Bitrate       Bitrate1   Buf_lev   Buf_limit     Elapsed  \
# count     144.000000     144.000000     144.0       144.0  144.000000
# mean   101724.256556  102295.444444       1.0         2.0    5.649432
# std     57954.832640   58325.061364       0.0         0.0    4.627829
# min     16804.587801   16840.000000       1.0         2.0    0.000055
# ...

# %%
data_merged = pd.concat([data1,data2,data3,data4,data5], ignore_index=True)


data_merged.describe()
# Out:
#           Tile_no      Seg_no   Reso    Seg_d_size   Seg_d_time  \
# count  720.000000  720.000000  720.0    720.000000   720.000000
# mean    16.020833    2.000000  720.0  10898.277778     0.117476
# std     11.944743    0.817064    0.0   5709.960020     0.054040
# min      0.000000    1.000000  720.0   5424.000000     0.102327
# 25%      5.000000    1.000000  720.0   6872.000000     0.103508
# 50%     14.500000    2.000000  720.0   8192.000000     0.103528
# 75%     26.250000    3.000000  720.0  14272.000000     0.103642
# max     38.000000    3.000000  720.0  33216.000000     0.335263
#
#              Bitrate       Bitrate1   Buf_lev   Buf_limit     Elapsed  \
# count     720.000000     720.000000     720.0       720.0  720.000000
# mean   101748.937331  102301.055556       1.0         2.0    5.648908
# std     57820.524372   58165.052263       0.0         0.0    4.615352
# min     16804.587801   16840.000000       1.0         2.0    0.000055
# ...

# %%
data_merged.hist()
# Out:
# array([[<Axes: title={'center': ' Tile_no'}>,
#         <Axes: title={'center': ' Seg_no'}>,
#         <Axes: title={'center': ' Reso'}>,
#         <Axes: title={'center': ' Seg_d_size'}>],
#        [<Axes: title={'center': ' Seg_d_time'}>,
#         <Axes: title={'center': ' Bitrate'}>,
#         <Axes: title={'center': ' Bitrate1'}>,
#         <Axes: title={'center': ' Buf_lev'}>],
#        [<Axes: title={'center': ' Buf_limit'}>,
#         <Axes: title={'center': ' Elapsed'}>,
#         <Axes: title={'center': ' Ref_vp'}>,
#         <Axes: title={'center': ' Local_avg'}>],
#        [<Axes: title={'center': 'QoE'}>,
#         <Axes: title={'center': 'QoE1'}>, <Axes: title={'center': 'Z1'}>,
#         <Axes: title={'center': 'Z2'}>],
#        [<Axes: title={'center': 'Z3'}>,
#         <Axes: title={'center': 'delay'}>,
#         <Axes: title={'center': 'jitter'}>,
#         <Axes: title={'center': 'loss'}>]], dtype=object)

# %%
data_merged.boxplot()
# Out:
# <Axes: >
