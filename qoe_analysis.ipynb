# %%
import pandas as pd
import os

folderClient_prefix = 'client_'

def run_analysis(basePath):
  final_data = pd.DataFrame()
  for i in range(1, 5):
    for j in range(1, 15):
        for k in range(1, 8):
          try:

            path = basePath +  str(i) + '/client_' + str(k) + '/' + str(j) + '/user1-session1_QoE.csv'
            if not os.path.exists(basePath):
              continue
            data = pd.read_csv(path)
            final_data = pd.concat([final_data, data], ignore_index=True)

          except Exception as a:
            pass
  
  return final_data

# %%
basePath243136Scheduler = './final_experiment/2-43-136/scheduler/'
data243136Scheduler = run_analysis(basePath243136Scheduler)

# %%
data243136Scheduler.describe()
# Out:
#             Tile_no        Seg_no     Reso    Seg_d_size    Seg_d_time  \
# count  54816.000000  54816.000000  54816.0  54816.000000  54816.000000
# mean      16.020833      2.984238    720.0  12808.969498      0.182857
# std       11.936554      1.440519      0.0   7972.527689      0.224170
# min        0.000000      1.000000    720.0      0.000000      0.050389
# 25%        5.000000      2.000000    720.0   6872.000000      0.103050
# 50%       14.500000      3.000000    720.0   9664.000000      0.143905
# 75%       26.250000      4.000000    720.0  16880.000000      0.144232
# max       38.000000      6.000000    720.0  43464.000000      9.613078
#
#              Bitrate       Bitrate1   Buf_lev   Buf_limit       Elapsed  \
# count   54816.000000   54816.000000   54816.0     54816.0  54816.000000
# mean    98634.626447   98896.833041       1.0         2.0     17.054096
# std     72251.928505   72409.463659       0.0         0.0     12.353769
# ...

# %%
basePath243136Default = './final_experiment/2-43-136/default/'
data243136Default = run_analysis(basePath243136Default)

# %%
data243136Default.describe()

# %%
data000 = run_analysis(basePath000)
data003 = run_analysis(basePath003)

data_merged = pd.concat([data000, data003], ignore_index=True)

# %%
data_merged.head(5)
# Out:
#   Zone   Tile_no   Seg_no  Reso   Seg_d_size   Seg_d_time       Bitrate  \
# 0   Z1         0        1   720       9960.0     0.018766  5.307471e+05
# 1   Z2         0        1   720       8952.0     0.023310  3.840412e+05
# 2   Z2         1        1   720       5424.0     0.000746  7.270777e+06
# 3   Z2         2        1   720       7080.0     0.000705  1.004255e+07
# 4   Z2         3        1   720      18976.0     0.000797  2.380928e+07
#
#      Bitrate1   Buf_lev   Buf_limit  ...        Ref_vp     Local_avg  \
# 0    553328.0       1.0           2  ...  5.307471e+05  5.307471e+05
# 1    389216.0       1.0           2  ...  1.920206e+05  1.920206e+05
# 2   5424000.0       1.0           2  ...  2.423592e+06  2.423592e+06
# 3   7080000.0       1.0           2  ...  2.510638e+06  2.510638e+06
# 4  18976000.0       1.0           2  ...  4.761857e+06  4.761857e+06
#
#             QoE          QoE1            Z1            Z2            Z3  \
# ...

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  4.798080e+06  4.798080e+06  4.798080e+06  4.798080e+06  4.798080e+06
# mean   1.602083e+01  8.000000e+00  8.261452e+04  5.288136e-03  4.802773e+07
# std    1.193645e+01  4.320494e+00  8.860346e+04  3.801864e-02  3.825123e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  2.730336e+03
# 25%    5.000000e+00  4.000000e+00  1.570000e+04  9.490000e-04  1.443968e+07
# 50%    1.450000e+01  8.000000e+00  5.076800e+04  1.183000e-03  4.074569e+07
# 75%    2.625000e+01  1.200000e+01  1.108040e+05  1.836000e-03  7.035038e+07
# max    3.800000e+01  1.500000e+01  5.527840e+05  3.278717e+00  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  4.798080e+06  4.798080e+06   4798080.0  4.798080e+06  4.798080e+06
# mean   6.180928e+07  1.425776e+00         2.0  4.079677e+00  3.493585e+07
# ...

# %%
data_merged.hist()
# Out:
# array([[<Axes: title={'center': ' Tile_no'}>,
#         <Axes: title={'center': ' Seg_no'}>,
#         <Axes: title={'center': ' Seg_d_size'}>,
#         <Axes: title={'center': ' Seg_d_time'}>],
#        [<Axes: title={'center': ' Bitrate'}>,
#         <Axes: title={'center': ' Bitrate1'}>,
#         <Axes: title={'center': ' Buf_lev'}>,
#         <Axes: title={'center': ' Buf_limit'}>],
#        [<Axes: title={'center': ' Elapsed'}>,
#         <Axes: title={'center': ' Ref_vp'}>,
#         <Axes: title={'center': ' Local_avg'}>,
#         <Axes: title={'center': 'QoE'}>],
#        [<Axes: title={'center': 'QoE1'}>, <Axes: title={'center': 'Z1'}>,
#         <Axes: title={'center': 'Z2'}>, <Axes: title={'center': 'Z3'}>],
#        [<Axes: title={'center': 'delay'}>,
#         <Axes: title={'center': 'jitter'}>,
#         <Axes: title={'center': 'loss'}>, <Axes: >]], dtype=object)

# %%
data_merged.boxplot()
# Out:
# <Axes: >
