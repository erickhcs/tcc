# %%
import pandas as pd

basePath = './0-0-0/client_'
data_merged = pd.DataFrame()

for i in range(1, 5):
  for j in range(1, 834):
    data = pd.read_csv(basePath + str(i) + '/' + str(j) + '/user1-session1_QoE.csv')
    data_merged = pd.concat([data_merged, data], ignore_index=True)

# %%
data_merged.head(5)
# Out:
#   Zone   Tile_no   Seg_no  Reso   Seg_d_size   Seg_d_time       Bitrate  \
# 0   Z1         0        1   720       9960.0     0.018766  5.307471e+05
# 1   Z2         0        1   720       8952.0     0.023310  3.840412e+05
# 2   Z2         1        1   720       5424.0     0.000746  7.270777e+06
# 3   Z2         2        1   720       7080.0     0.000705  1.004255e+07
# 4   Z2         3        1   720      18976.0     0.000797  2.380928e+07
#
#      Bitrate1   Buf_lev   Buf_limit  ...        Ref_vp     Local_avg  \
# 0    553328.0       1.0           2  ...  5.307471e+05  5.307471e+05
# 1    389216.0       1.0           2  ...  1.920206e+05  1.920206e+05
# 2   5424000.0       1.0           2  ...  2.423592e+06  2.423592e+06
# 3   7080000.0       1.0           2  ...  2.510638e+06  2.510638e+06
# 4  18976000.0       1.0           2  ...  4.761857e+06  4.761857e+06
#
#             QoE          QoE1            Z1            Z2            Z3  \
# 0  1.823679e+09  4.733381e+09  4.762855e+07  5.967797e+09  3.506482e+10
# 1  1.823679e+09  4.733381e+09  4.762855e+07  5.967797e+09  3.506482e+10
# 2  1.823679e+09  4.733381e+09  4.762855e+07  5.967797e+09  3.506482e+10
# 3  1.823679e+09  4.733381e+09  4.762855e+07  5.967797e+09  3.506482e+10
# 4  1.823679e+09  4.733381e+09  4.762855e+07  5.967797e+09  3.506482e+10
#
#    delay  jitter  loss
# 0      0       0     0
# 1      0       0     0
# 2      0       0     0
# 3      0       0     0
# 4      0       0     0
#
# [5 rows x 21 columns]

# %%
data_merged.describe()
# Out:
#             Tile_no        Seg_no    Seg_d_size    Seg_d_time       Bitrate  \
# count  2.399040e+06  2.399040e+06  2.399040e+06  2.399040e+06  2.399040e+06
# mean   1.602083e+01  8.000000e+00  8.261452e+04  2.664059e-03  5.315420e+07
# std    1.193645e+01  4.320495e+00  8.860347e+04  5.317409e-03  4.269755e+07
# min    0.000000e+00  1.000000e+00  5.424000e+03  4.310000e-04  1.586549e+05
# 25%    5.000000e+00  4.000000e+00  1.570000e+04  9.460000e-04  1.522366e+07
# 50%    1.450000e+01  8.000000e+00  5.076800e+04  1.170000e-03  4.388755e+07
# 75%    2.625000e+01  1.200000e+01  1.108040e+05  1.582000e-03  7.858452e+07
# max    3.800000e+01  1.500000e+01  5.527840e+05  4.175100e-02  2.642371e+08
#
#            Bitrate1       Buf_lev   Buf_limit       Elapsed        Ref_vp  \
# count  2.399040e+06  2.399040e+06   2399040.0  2.399040e+06  2.399040e+06
# mean   6.962563e+07  1.459019e+00         2.0  3.528912e+00  3.782907e+07
# std    6.736574e+07  2.990100e-01         0.0  2.477289e+00  2.745476e+07
# min    1.615600e+05  1.000000e+00         2.0  1.700000e-05  3.859047e+04
# 25%    1.324000e+07  1.226246e+00         2.0  1.365963e+00  1.468556e+07
# 50%    4.560800e+07  1.449525e+00         2.0  3.864820e+00  3.026338e+07
# 75%    1.044400e+08  1.720587e+00         2.0  5.393742e+00  6.075330e+07
# max    4.816560e+08  1.999883e+00         2.0  8.068776e+00  1.152804e+08
#
#           Local_avg           QoE          QoE1            Z1            Z2  \
# count  2.399040e+06  2.399040e+06  2.399040e+06  2.399040e+06  2.399040e+06
# mean   3.782907e+07  1.715240e+09  4.418764e+09  5.431289e+07  5.590736e+09
# std    2.745476e+07  6.704219e+07  9.315880e+07  3.171267e+06  2.265417e+08
# min    3.859047e+04  1.510495e+09  4.150584e+09  4.292332e+07  4.900128e+09
# 25%    1.468556e+07  1.662504e+09  4.350446e+09  5.230357e+07  5.411852e+09
# 50%    3.026338e+07  1.713441e+09  4.409392e+09  5.368270e+07  5.584663e+09
# 75%    6.075330e+07  1.770999e+09  4.484859e+09  5.657186e+07  5.780792e+09
# max    1.152804e+08  1.905989e+09  4.733381e+09  6.326204e+07  6.230115e+09
#
#                  Z3      delay     jitter       loss
# count  2.399040e+06  2399040.0  2399040.0  2399040.0
# mean   3.262598e+10        0.0        0.0        0.0
# std    6.222285e+08        0.0        0.0        0.0
# min    3.063560e+10        0.0        0.0        0.0
# 25%    3.218548e+10        0.0        0.0        0.0
# 50%    3.260572e+10        0.0        0.0        0.0
# 75%    3.304895e+10        0.0        0.0        0.0
# max    3.506482e+10        0.0        0.0        0.0

# %%
data_merged.hist()
# Out:
# array([[<Axes: title={'center': ' Tile_no'}>,
#         <Axes: title={'center': ' Seg_no'}>,
#         <Axes: title={'center': ' Seg_d_size'}>,
#         <Axes: title={'center': ' Seg_d_time'}>],
#        [<Axes: title={'center': ' Bitrate'}>,
#         <Axes: title={'center': ' Bitrate1'}>,
#         <Axes: title={'center': ' Buf_lev'}>,
#         <Axes: title={'center': ' Buf_limit'}>],
#        [<Axes: title={'center': ' Elapsed'}>,
#         <Axes: title={'center': ' Ref_vp'}>,
#         <Axes: title={'center': ' Local_avg'}>,
#         <Axes: title={'center': 'QoE'}>],
#        [<Axes: title={'center': 'QoE1'}>, <Axes: title={'center': 'Z1'}>,
#         <Axes: title={'center': 'Z2'}>, <Axes: title={'center': 'Z3'}>],
#        [<Axes: title={'center': 'delay'}>,
#         <Axes: title={'center': 'jitter'}>,
#         <Axes: title={'center': 'loss'}>, <Axes: >]], dtype=object)

# %%
data_merged.boxplot()
# Out:
# <Axes: >
